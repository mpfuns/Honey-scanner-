# %%
#import  the data 
import pandas as pd
df = pd.read_csv('documents/ai/Honey scanner/Honey-/vgsales.csv')
df.shape
df.describe()
df.values  
##clean the data 
# remove missing vaules , duplicate rows 

#split the data  into training/test sets

#Create a model 

# train  the model

# make  predictions 

# evalute and improve
